# %%
from urllib import parse

import os
import sys
sys.path.append(r"D:\往期\QHJ\ZERO")
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

from tools import *

# %%
file_path = r'D:\奇货居\素材\商城图片素材\商品信息.xlsx'
data = pd.read_excel(file_path)

# %%
data[['商品ID','类别','类别模式','售价']]

# %%
data
# Out:
#     序号                商品ID       类别       规格模式             规格  \
# 0    1  S0001P0001C0001P01      NaN         颜色              蓝
# 1    2  S0001P0001C0001P02      NaN         颜色              红
# 2    3  S0001P0001C0001P03      NaN         颜色              灰
# 3    4  S0001P0001C0002P01      NaN         颜色              黑
# 4    5  S0001P0001C0002P02      NaN         颜色              红
# 5    6  S0001P0001C0003P01      NaN         颜色              黑
# 6    7  S0001P0001C0003P02      NaN         颜色              灰
# 7    8  S0001P0001C0003P03      NaN         颜色              蓝
# 8    9  S0001P0002C0001P01      NaN        NaN            NaN
# 9   10  S0001P0002C0002P01      NaN        NaN            NaN
# 10  11  S0001P0002C0003P01      NaN        NaN            NaN
# 11  12  S0001P0003C0001P01      NaN        NaN            NaN
# 12  13  S0001P0003C0002P01      NaN        NaN            NaN
# 13  14  S0001P0003C0003P01      NaN        NaN            NaN
# ...

# %%
stop

# %%
# 添加规格
:authority: app0001.yrapps.cn
:method: POST
:path: /admin/goodattribute/up_good_attr_conf
:scheme: https
accept: application/json, text/plain, */*
accept-encoding: gzip, deflate, br
accept-language: zh-CN,zh;q=0.9,en;q=0.8
content-length: 1096
content-type: application/x-www-form-urlencoded
cookie: PHPSESSID=d20rjmn4bhjt3qgs2cpvcfa2rs
origin: https://app0001.yrapps.cn
referer: https://app0001.yrapps.cn/admin/goodattribute/good_attr_conf.html?goods_id=7&a=1.html
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36


goods_id: 7
attr_list[0][attr_name_list][0][attr_name]: 金色
attr_list[0][attr_name_list][1][attr_name]: 64G
attr_list[0][attr_name]: 金色64G
attr_list[0][attr_price]: 9300
attr_list[0][attr_stock]: 100
attr_list[0][goods_id]: 7

# %%
# 增加 商品
:authority: app0001.yrapps.cn
:method: POST
:path: /admin/good/add_good.html
:scheme: https
accept: */*
accept-encoding: gzip, deflate, br
accept-language: zh-CN,zh;q=0.9,en;q=0.8
content-length: 65
content-type: application/x-www-form-urlencoded; charset=UTF-8
cookie: PHPSESSID=d20rjmn4bhjt3qgs2cpvcfa2rs
origin: https://app0001.yrapps.cn
referer: https://app0001.yrapps.cn/admin/good/good_add/is_free/0.html
sec-fetch-mode: cors
sec-fetch-site: same-origin
user-agent: Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36
x-requested-with: XMLHttpRequest
goods_name: xxx
class_id: 7
fake_sales: 12
goods_info: xzzx
is_free: 0

# %%
#　修改属性
import requests
headers = {

"accept": "*/*",
"accept-encoding": "gzip, deflate, br",
"accept-language": "zh-CN,zh;q=0.9,en;q=0.8",
"content-length": "21",
"content-type": "application/x-www-form-urlencoded; charset=UTF-8",
"cookie": "PHPSESSID=d20rjmn4bhjt3qgs2cpvcfa2rs",
"origin": "https://app0001.yrapps.cn",
"referer": "https://app0001.yrapps.cn/admin/Good/goodList",
"sec-fetch-mode": "cors",
"sec-fetch-site": "same-origin",
"user-agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
"x-requested-with": "XMLHttpRequest",
}



data = {
    "goods_id": 6,
    'is_shelf': 1
    
}
url = 'https://app0001.yrapps.cn/admin/good/good_opt_shelf.html'
requests.post(url,data=data,headers=headers)
# Out:
# <Response [200]>

# %%
    
    
    


    data = {
    "goods_id": 1,
    'send_price': 30.4,
    'sort':102
}
url = 'https://app0001.yrapps.cn/admin/good/good_opt_data.html'
requests.post(url,data=data,headers=headers)
# Out:
# <Response [200]>

# %%
# 是否为推荐
https://app0001.yrapps.cn/admin/good/good_opt_tui.html
    
goods_id: 6
is_tui: 1

# %%
https://app0001.yrapps.cn/admin/good/good_opt_data.html

# %%
from pprint import pprint

# %%
# Out:
# goods_id                        1
# info_setting    法国大使（Delsey）双肩休闲包
# Name: 0, dtype: object
# goods_id                         2
# info_setting    法国大使（Delsey）商务电脑背包
# Name: 1, dtype: object
# goods_id                         3
# info_setting    法国大使（Delsey）商务旅行背包
# Name: 2, dtype: object
# goods_id                  6
# info_setting    LOVO经典床上四件套
# Name: 3, dtype: object
# goods_id                        7
# info_setting    iPhone 11 Pro MAX
# Name: 4, dtype: object
# goods_id                         8
# info_setting    HUAWEI Mate 30 Pro
# Name: 5, dtype: object
# goods_id                    9
# info_setting    AirSolo单耳蓝牙耳机
# Name: 6, dtype: object
# goods_id               10
# info_setting    LOVO 魅力格调
# Name: 7, dtype: object
# goods_id               11
# info_setting    LOVO 唯美田园
# Name: 8, dtype: object

# %%
df
# Out:
#     goods_id        info_setting     attr_goods_code attr_name  \
# 0          1   法国大使（Delsey）双肩休闲包                 NaN       NaN
# 1          2  法国大使（Delsey）商务电脑背包                 NaN       NaN
# 2          3  法国大使（Delsey）商务旅行背包                 NaN       NaN
# 3          6         LOVO经典床上四件套                 NaN       NaN
# 4          7   iPhone 11 Pro MAX  S0002P0001C0001P01     金色64G
# 5          7   iPhone 11 Pro MAX  S0002P0001C0001P02    金色256G
# 6          7   iPhone 11 Pro MAX  S0002P0001C0001P03    金色512G
# 7          7   iPhone 11 Pro MAX  S0002P0001C0001P04      暗夜绿色
# 8          7   iPhone 11 Pro MAX  S0002P0001C0001P05      暗夜绿色
# 9          7   iPhone 11 Pro MAX  S0002P0001C0001P06      暗夜绿色
# 10         7   iPhone 11 Pro MAX  S0002P0001C0001P07   深空灰色64G
# 11         7   iPhone 11 Pro MAX  S0002P0001C0001P08  深空灰色256G
# 12         7   iPhone 11 Pro MAX  S0002P0001C0001P09  深空灰色512G
# 13         7   iPhone 11 Pro MAX  S0002P0001C0001P10     银色64G
# ...
