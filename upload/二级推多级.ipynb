# %%
import os
import sys
sys.path.append(r"E:\dataparse\Python_DATA_PARSE\qhj\ZERO")

import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

from tools import *

# %%
file_path = r"C:\Users\zero\Desktop\TEST.xlsx"

df = pd.read_excel(file_path)
data = df.copy()
data['grandfather_id'] = 0
data['grandfather'] = None
data['level'] = 1
data['root'] = None
data['root_name'] = None
data['二级佣金'] = 0
data['三级佣金'] = 0
data['无限极佣金'] = 0


commission_dic = {
    "VIP":20,
    "VVIP":50
}

data['root'][data['parent_id'] == 0] = data[data['parent_id'] == 0]['user_id']
data['root_name'][data['parent_id'] == 0] = data[data['parent_id'] == 0]['user_name']
data = data.set_index('user_id',drop=False)

# %%
data[:3]
# Out:
#          user_id user_name parent_name  parent_id state  grandfather_id  \
# user_id
# 1              1        A1        root          0   合伙人               0
# 2              2        A2        root          0  VVIP               0
# 3              3        B1          A1          1  VVIP               0
#
#         grandfather  level  root root_name  二级佣金  三级佣金  无限极佣金
# user_id
# 1              None      1     1        A1     0     0      0
# 2              None      1     2        A2     0     0      0
# 3              None      1  None      None     0     0      0

# %%
data.loc[[1,2],['user_name','parent_name']]
# Out:
#         user_name parent_name
# user_id
# 1              A1        root
# 2              A2        root

# %%
for index,row in data.iterrows():
    parent_id = row['parent_id']
    state = row['state']
    commission = commission_dic.get(state,0)
    

    # 二级
    if parent_id:

        data.loc[index,'level'] += data.loc[parent_id,'level']
        data.loc[index,'root'] = data.loc[parent_id,'root']
        data.loc[index,'root_name'] = data.loc[parent_id,'root_name']
        
        data.loc[parent_id,'二级佣金'] +=  commission
        data.loc[parent_id,'无限极佣金'] +=  commission
        
        parent_id = data.loc[parent_id,'parent_id']
    
    # 三级
    if parent_id:
        data.loc[parent_id,'三级佣金'] += commission
        data.loc[parent_id,'无限极佣金'] +=  commission
        
        data.loc[index,'grandfather_id'] =  parent_id
        data.loc[index,'grandfather'] =  data.loc[parent_id,'user_name']
        
        parent_id = data.loc[parent_id,'parent_id']

    while parent_id:
        data.loc[parent_id,'无限极佣金'] +=  commission
        parent_id = data.loc[parent_id,'parent_id']

# %%
s = set(data['grandfather_id'].unique())
s.remove(0)
s
# Out:
# {1, 2, 4, 5, 8, 9}

# %%
data.to_excel(r"C:\Users\zero\Desktop\T\处理后的数据.xlsx",index=False)

# %%
temp = data[['state','user_id', 'user_name', 'parent_id', 'parent_name', 'grandfather', 'grandfather_id']]. \
dropna().rename(columns={"user_name":"三级用户名",
                         'state':"三级用户等级",
                         'parent_name':"二级用户名"})
temp['可抽取佣金'] = temp['三级用户等级'].apply(lambda x:commission_dic.get(x,0))

# %%
save_dir = r"C:\Users\zero\Desktop\T\需要发送的三级名单"
for (grandfather,grandfather_id),t in temp.groupby(['grandfather','grandfather_id']):
    t=  t[['二级用户名','三级用户名','三级用户等级','可抽取佣金']].sort_values('二级用户名')
    save_path = os.path.join(save_dir, '%s_%s.xlsx' %(grandfather_id,grandfather))
    t.to_excel(save_path, index=False)

# %%
data[['user_id', 'user_name', 'pareant_id', 'parent_name', 'grandfather', 'grandfather_id']]
# Out:
#          user_id user_name parent_name  parent_id state  grandfather_id  \
# user_id
# 1              1        A1        root          0   合伙人               0
# 2              2        A2        root          0  VVIP               0
# 3              3        B1          A1          1  VVIP               0
# 4              4        B2          A1          1  VVIP               0
# 5              5        B3          A1          1  VVIP               0
# 6              6        B4          A1          1   VIP               0
# 7              7        B5          A2          2  VVIP               0
# 8              8        B6          A2          2  VVIP               0
# 9              9        B7          A2          2  VVIP               0
# 10            10        C1          B1          3   VIP               1
# 11            11        C2          B2          4  VVIP               1
# 12            12        C3          B2          4   VIP               1
# 13            13        C4          B3          5  VVIP               1
# 14            14        C5          B3          5  VVIP               1
# 15            15        C6          B5          7   VIP               2
# 16            16        C7          B6          8  VVIP               2
# 17            17        C8          B6          8  VVIP               2
# 18            18        C9          B7          9  VVIP               2
# 19            19       C10          B7          9  VVIP               2
# 20            20        D1          C2         11  VVIP               4
# 21            21        D2          C2         11   VIP               4
# 22            22        D3          C4         13  VVIP               5
# 23            23        D4          C7         16   VIP               8
# 24            24        D5          C8         17  VVIP               8
# 25            25        D6         C10         19  VVIP               9
#
#         grandfather  level  root root_name  二级佣金  三级佣金  无限极佣金
# user_id
# 1              None      1     1        A1   170   190    480
# 2              None      1     2        A2   150   220    490
# 3              None      2     1        A1    20     0     20
# 4              None      2     1        A1    70    70    140
# 5              None      2     1        A1   100    50    150
# 6              None      2     1        A1     0     0      0
# 7              None      2     2        A2    20     0     20
# 8              None      2     2        A2   100    70    170
# 9              None      2     2        A2   100    50    150
# 10               A1      3     1        A1     0     0      0
# 11               A1      3     1        A1    70     0     70
# 12               A1      3     1        A1     0     0      0
# 13               A1      3     1        A1    50     0     50
# 14               A1      3     1        A1     0     0      0
# 15               A2      3     2        A2     0     0      0
# 16               A2      3     2        A2    20     0     20
# 17               A2      3     2        A2    50     0     50
# 18               A2      3     2        A2     0     0      0
# 19               A2      3     2        A2    50     0     50
# 20               B2      4     1        A1     0     0      0
# 21               B2      4     1        A1     0     0      0
# 22               B3      4     1        A1     0     0      0
# 23               B6      4     2        A2     0     0      0
# 24               B6      4     2        A2     0     0      0
# 25               B7      4     2        A2     0     0      0

# %%
data
# Out:
#          user_id user_name parent_name  parent_id state  grandfather_id  \
# user_id
# 1              1        A1        root          0   合伙人               0
# 2              2        A2        root          0  VVIP               0
# 3              3        B1          A1          1  VVIP               0
# 4              4        B2          A1          1  VVIP               0
# 5              5        B3          A1          1  VVIP               0
# 6              6        B4          A1          1   VIP               0
# 7              7        B5          A2          2  VVIP               0
# 8              8        B6          A2          2  VVIP               0
# 9              9        B7          A2          2  VVIP               0
# 10            10        C1          B1          3   VIP               1
# 11            11        C2          B2          4  VVIP               1
# 12            12        C3          B2          4   VIP               1
# 13            13        C4          B3          5  VVIP               1
# 14            14        C5          B3          5  VVIP               1
# 15            15        C6          B5          7   VIP               2
# 16            16        C7          B6          8  VVIP               2
# 17            17        C8          B6          8  VVIP               2
# 18            18        C9          B7          9  VVIP               2
# 19            19       C10          B7          9  VVIP               2
# 20            20        D1          C2         11  VVIP               4
# 21            21        D2          C2         11   VIP               4
# 22            22        D3          C4         13  VVIP               5
# 23            23        D4          C7         16   VIP               8
# 24            24        D5          C8         17  VVIP               8
# 25            25        D6         C10         19  VVIP               9
#
#         grandfather  level  root root_name  二级佣金  三级佣金  无限极佣金
# user_id
# 1              None      1     1        A1   170   190    480
# 2              None      1     2        A2   150   220    490
# 3              None      2     1        A1    20     0     20
# 4              None      2     1        A1    70    70    140
# 5              None      2     1        A1   100    50    150
# 6              None      2     1        A1     0     0      0
# 7              None      2     2        A2    20     0     20
# 8              None      2     2        A2   100    70    170
# 9              None      2     2        A2   100    50    150
# 10               A1      3     1        A1     0     0      0
# 11               A1      3     1        A1    70     0     70
# 12               A1      3     1        A1     0     0      0
# 13               A1      3     1        A1    50     0     50
# 14               A1      3     1        A1     0     0      0
# 15               A2      3     2        A2     0     0      0
# 16               A2      3     2        A2    20     0     20
# 17               A2      3     2        A2    50     0     50
# 18               A2      3     2        A2     0     0      0
# 19               A2      3     2        A2    50     0     50
# 20               B2      4     1        A1     0     0      0
# 21               B2      4     1        A1     0     0      0
# 22               B3      4     1        A1     0     0      0
# 23               B6      4     2        A2     0     0      0
# 24               B6      4     2        A2     0     0      0
# 25               B7      4     2        A2     0     0      0
