# %%
from urllib import parse

import os
import sys
sys.path.append(r"D:\往期\QHJ\ZERO")
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import pymysql
from sqlalchemy import create_engine

from tools import *

# %%
file_path = r'D:\奇货居\素材\商城图片素材\商品信息.xlsx'
data = pd.read_excel(file_path)

# %%
from pprint import pprint

# %%
headers = {
    "accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3",
"accept-encoding": "gzip, deflate, br",
"accept-language": "zh-CN,zh;q=0.9,en;q=0.8",
"cookie": "PHPSESSID=jcoai16uuq95trcp819jrud2vl",
"referer": "https://app0001.yrapps.cn/admin/Good/goodList",
"sec-fetch-mode": "nested-navigate",
"sec-fetch-site": "same-origin",
"upgrade-insecure-requests": "1",
"user-agent": "Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36",
}

# %%
url = "https://app0001.yrapps.cn/admin/Good/goodList"
html = requests.get(url,headers = headers).text
from pyquery import PyQuery as pq
#初始化为PyQuery对象
doc = pq(html,parser="html")


l = []
for tr in doc("tbody tr"):
    d = {}
    img = tr.cssselect('.goods_img')
#     img = item.find('.goods_img')
#     print(img)
    info = tr.cssselect('.info_setting')
    d['goods_id'] = img[0].attrib['goods_id']
    d['info_setting'] = info[0].text.strip()
    
    l.append(d)
data = pd.DataFrame(l)

# %%
data
# Out:
#   goods_id        info_setting
# 0        1   法国大使（Delsey）双肩休闲包
# 1        2  法国大使（Delsey）商务电脑背包
# 2        3  法国大使（Delsey）商务旅行背包
# 3        6         LOVO经典床上四件套
# 4        7   iPhone 11 Pro MAX
# 5        8  HUAWEI Mate 30 Pro
# 6        9       AirSolo单耳蓝牙耳机
# 7       10           LOVO 魅力格调
# 8       11           LOVO 唯美田园
# 9       14            蓝牙音箱AP06

# %%
url = "https://app0001.yrapps.cn/admin/goodattribute/good_goodattribute?goods_id=7"



rep = requests.get(url,headers= headers)
jxx = rep.json()
data_item = pd.DataFrame(jxx['select_list'])
def t(x):
    l = []
    for row in x:
        l.append(row['attr_name'])
    return '|'.join(l)
data_item['类别'] = data['attr_name_list'].apply(t)
# Out:
# <class 'pyquery.pyquery.PyQuery'>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8"/>
# 	<title>[title]</title>
#     <meta name="renderer" content="webkit|ie-comp|ie-stand"/>
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>
#     <meta name="viewport" content="width=device-width,user-scalable=yes, minimum-scale=0.4, initial-scale=0.8"/>
#     <meta http-equiv="Cache-Control" content="no-siteapp"/>
#     <link rel="stylesheet" href="/static/layui/css/layui.css"/>
#     <link rel="stylesheet" href="/static/layui/css/admin.css"/>
#     <link rel="stylesheet" href="/static/layui/css/login.css"/>
#     <script src="/static/layui/jquery.min.js"/>
#     <script src="/static/layui/layui.js" charset="utf-8"/>
#     <script src="/static/pub/echarts.min.js"/>
#     <script src="/static/pub/vue.js"/>
#     <script src="/static/pub/axios.min.js"/>
#     <script src="/static/pub/qs.min.js"/>
#     <!--[if lt IE 9]>
# ...

# %%
for item in doc("tbody .goods_img"):
    print(item.attrib['goods_id'])
#     img = item.find('.goods_img')
#     print(img)
#     info = item.find('.info_setting')
#     print(item.find('.info_setting'))
# Out:
# 1
# 2
# 3
# 6
# 7
# 8
# 9
# 10
# 11
